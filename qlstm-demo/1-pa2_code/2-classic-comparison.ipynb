# %%
import pandas as pd
import utils.plot_functions as pf

# %%
# import lstm metrics
lstm = pd.read_csv("data/lstm_metrics.csv")
lstm_damped_oscillator = lstm[lstm["data"] == "data/data_damped_oscillator.csv"]
lstm_custom_data = lstm[lstm["data"] == "data/custom_created_pattern.csv"]

# %%
print("Damped Oscillator")
lstm_damped_oscillator.groupby('epochs')['model_name'].count().reset_index().rename(columns={'model_name':'run_count'})
# Out:
# Damped Oscillator
#    epochs  run_count
# 0       1       1000
# 1       5       1000
# 2      15       1000
# 3      30       1000
# 4      50       1000

# %%
print("Custom Data")
lstm_custom_data.groupby('epochs')['model_name'].count().reset_index().rename(columns={'model_name':'run_count'})
# Out:
# Custom Data
#    epochs  run_count
# 0       1       1000
# 1       5       1000
# 2      15       1000
# 3      30       1000
# 4      50       1000

# %%
# import qlstm metrics
qlstm = pd.read_csv("data/qlstm_metrics.csv")
qlstm_damped_oscillator = qlstm[(qlstm["FeatureMap"] == "paper_3") & (qlstm["data"] == "data/data_damped_oscillator.csv")]
qlstm_custom_data = qlstm[(qlstm["FeatureMap"] == "paper_3") & (qlstm["data"] == "data/custom_created_pattern.csv")]

# %%
print("Damped Oscillator")
qlstm_damped_oscillator.groupby('epochs')['model_name'].count().reset_index().rename(columns={'model_name':'run_count'})
# Out:
# Damped Oscillator
#    epochs  run_count
# 0       1         50
# 1       5         38
# 2      15         30
# 3      30         27
# 4      50         26

# %%
print("Custom Data")
qlstm_custom_data.groupby('epochs')['model_name'].count().reset_index().rename(columns={'model_name':'run_count'})
# Out:
# Custom Data
#    epochs  run_count
# 0       1         50
# 1       5         30
# 2      15         30
# 3      30         15
# 4      50         23

# %%
pf.create_epoch_plot(lstm_damped_oscillator, qlstm_damped_oscillator, "Damped Oscillator")

# %%
# build evaluation metric dataframes
lstm_do_metrics = lstm_damped_oscillator[["epochs", "mse_train", "mse_test", "mae_train", "mae_test"]]
qlstm_do_metrics = qlstm_damped_oscillator[["epochs", "mse_train", "mse_test", "mae_train", "mae_test"]]

# %%
pf.create_boxplot(lstm_do_metrics, qlstm_do_metrics, "mse_train", "Boxplots of MSE - Train: Damped Oscillator")

# %%
pf.create_boxplot(lstm_do_metrics, qlstm_do_metrics, "mse_test", "Boxplots of MSE - Test: Damped Oscillator")

# %%
pf.create_epoch_plot(lstm_custom_data, qlstm_custom_data, "Damped Oscillator")

# %%
# build evaluation metric dataframes
lstm_cd_metrics = lstm_custom_data[["epochs", "mse_train", "mse_test", "mae_train", "mae_test"]]
qlstm_cd_metrics = qlstm_custom_data[["epochs", "mse_train", "mse_test", "mae_train", "mae_test"]]

# %%
pf.create_boxplot(lstm_cd_metrics, qlstm_cd_metrics, "mse_train", "Boxplots of MSE - Train: Custom Data")

# %%
pf.create_boxplot(lstm_cd_metrics, qlstm_cd_metrics, "mse_test", "Boxplots of MSE - Test: Custom Data")
