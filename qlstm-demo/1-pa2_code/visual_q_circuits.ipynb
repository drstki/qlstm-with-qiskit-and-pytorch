# %%
from qiskit import QuantumCircuit
import custom_circuits as cc

# %%
# paper_1
fm_1 = cc.FeatureMap_1()
vl_1 = cc.VariationalLayer_1()
paper_1 = QuantumCircuit(4)

# add the feature map and variational layer to the circuit
paper_1.compose(fm_1, inplace=True)
paper_1.compose(vl_1, inplace=True)


# paper_2
fm_2 = cc.FeatureMap_2()
vl_2 = cc.VariationalLayer_2()
paper_2 = QuantumCircuit(4)

# add the feature map and variational layer to the circuit
paper_2.compose(fm_2, inplace=True)
paper_2.compose(vl_2, inplace=True)


# paper_3
fm_3 = cc.FeatureMap_3()
vl_3 = cc.VariationalLayer_2()
paper_3 = QuantumCircuit(4)

# add the feature map and variational layer to the circuit
paper_3.compose(fm_3, inplace=True)
paper_3.compose(vl_3, inplace=True)


# paper_4
fm_4 = cc.FeatureMap_4()
vl_4 = cc.VariationalLayer_4()
paper_4 = QuantumCircuit(4)

# add the feature map and variational layer to the circuit
paper_4.compose(fm_4, inplace=True)
paper_4.compose(vl_4, inplace=True)

# %%
paper_1.draw(output='mpl')

# %%
paper_2.draw(output='mpl')

# %%
paper_3.draw(output='mpl')

# %%
paper_4.draw(output='mpl')
